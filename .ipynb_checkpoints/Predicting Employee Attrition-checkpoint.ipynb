# %% [markdown]
# # Predicting Employee Attrition
#
# Both as an interesting topic and being on the receiving end of company who doesn't know how to keep employees; I'm interested in investigating what markers could point to an employee's change of job and what companies can do to change that narrative. I'll be using IBM's ficticous data set to test correlations between various factors and attrition.
#
# Hopefully later I'll be able to put together some preditions on a real data set

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chisquare

ibm = pd.read_excel("Employee-Attrition.xlsx")
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Look at Existing Data
# I want to make sure, before I test any correlations, that there aren't null or unexpected values in some of the key columns. This could lead to erroneous results that may be hard to detect. I'll use Value Counts to see what is in the row and if there are any values I need to be aware of. Likely, this data is polished from the beginning since it is fictitional.

# %%
print(ibm["BusinessTravel"].value_counts())
print(ibm["EducationField"].value_counts())
print(ibm["Department"].value_counts())
print(ibm["Attrition"].value_counts())
print(ibm["JobRole"].value_counts())
print(ibm["MaritalStatus"].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# As expected, this data is pretty clean.
#
# # Data Types
#
# Because I want to see the correlations for this entire dataset, everything has to be an integer or float to support the square root and other functions that go into pearsons' r value. At the very least, I need to change the Attrition column (the whole point of this study) to be able to be calculated in the correlations!

# %%
types = ibm.dtypes
print(types)
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
work = ibm.select_dtypes(include=[object])
print(work.head())
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %% [markdown]
# Looks like nine columns to convert. I'll map all of the subsequent responses to numerical values, then keep those values for any graphs later on (should they prove to be correlated).

# %%
#This will work on the Attrition and OverTime columns
yesno = {"Yes": 1,
        "No": 0}

#business travel
travel = {"Non-Travel": 0,
         "Travel_Rarely": 1,
         "Travel_Frequently": 2}

#department
dept = {"Sales": 0,
       "Research & Development": 1, 
        "Human Resources": 2}

#education field
education = {"Life Sciences": 0, 
            "Medical": 1,
            "Marketing": 2,
            "Technical Degree": 3,
            "Other": 4,
            "Human Resources": 5}

#gender
gender = {"Female": 1,
         "Male": 0}

#job role
job = {"Sales Executive":0,
       "Research Scientist": 1,
       "Laboratory Technician": 2,
       "Manufacturing Director": 3,
       "Healthcare Representative": 4,
       "Manager": 5,
       "Sales Representative": 6,
       "Research Director": 7,
        "Human Resources": 8}

#marital Status
married = {"Single": 0,
           "Married" :1,
           "Divorced" :2}

#over 18
adult = {"Y": 1,
        "N": 0}

# %%
ibm["Attrition"].replace(yesno, inplace = True)
ibm["OverTime"].replace(yesno, inplace = True)
ibm["BusinessTravel"].replace(travel, inplace = True)
ibm["Department"].replace(dept, inplace = True)
ibm["EducationField"].replace(education, inplace = True)
ibm["Gender"].replace(gender, inplace = True)
ibm["JobRole"].replace(job, inplace = True)
ibm["MaritalStatus"].replace(married, inplace = True)
ibm["Over18"].replace(adult, inplace = True)

# %%
ibm.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           0                 1
# 1   49          0               2        279           1                 8
# 2   37          1               1       1373           1                 2
# 3   33          0               2       1392           1                 3
# 4   27          0               1        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               0              1               1
# 1          1               0              1               2
# 2          2               4              1               4
# 3          4               0              1               5
# 4          1               1              1               7
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# ...

# %%
ibm.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel              int64
# DailyRate                   int64
# Department                  int64
# DistanceFromHome            int64
# Education                   int64
# EducationField              int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int64
# JobSatisfaction             int64
# MaritalStatus               int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int64
# OverTime                    int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# ...

# %% [markdown]
# Now that everything is an interger, we can finally crank out some correlations.
#
# # Correlations

# %%
correlations = ibm.corr()
corr_a = correlations["Attrition"]
print(corr_a.sort_values())
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# MaritalStatus              -0.162070
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# Department                 -0.063991
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# Gender                     -0.029453
# JobRole                    -0.027930
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# PerformanceRating           0.002889
# ...

# %% [markdown]
# Not a lot stands out besides Overtime. The general threshold is for a correlation value of .25 or more, Overtime barely makes the cut. It makes sense though, that there are a wide variety of factors that can contribute to something like this. Perhaps we're missing columns of key data, or perhaps the issue is that complex.
#
# Remember, I also coded some of the options that could effect this outcome. Let's graph this and try to dig deeper.
#
# # Graphing

# %%
survey_fields = ibm.columns
survey_fields = [x for x in survey_fields]
survey_fields
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
fig, ax = plt.subplots()
fig = fig.set_size_inches(10,8)
ax.grid(False)
ax = sns.barplot(survey_fields, corr_a, color = "teal", saturation=.8)
plt.xticks(rotation=85)
plt.axhline(.15, c = "gray", alpha = 0.5)
plt.axhline(-.15, c = "gray", alpha = 0.5)
plt.ylabel("Pearson Correlation")
plt.title("Pearson Correlations for Employee Attrition")
# Out:
# Text(0.5,1,'Pearson Correlations for Employee Attrition')

# %% [markdown]
# # Preliminary Results
#
# I lowered the threshold to +/- .15 to capture more factors. Here, we have Age, Job Level, Monthly Income, Overtime, Total Working Years, Years with Current Role, and Years with Current Manager. Interestingly, besides Overtime, none of these are the ones that I coded earlier. It's worthwhile to note that while these have high correlations, we don't know which direction some of them lean. For example, age. It's correlated to attrition, but is that just for retired people or younger professionals getting their career going?
#
# Some interesting items that were not correlated, Salary Hikes, Hourly Rates, Education, and Job Role. This is ficticous data, but those are all strange things to consider as not necessarily effecting attrition.
